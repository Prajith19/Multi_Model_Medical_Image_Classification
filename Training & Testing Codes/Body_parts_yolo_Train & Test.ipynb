# %%
# !pip3 install ultralytics

# %%
# !unzip /content/drive/MyDrive/body.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: body/training/Shoulder/69a36920-9de7-4c0a-b07b-bceaedf8c826.png
#   inflating: body/training/Shoulder/69a3a322-3024-499b-87a1-24ec074007c2.png
#   inflating: body/training/Shoulder/69a9c013-47c4-4a3a-86a2-5ef8699f5e9e.png
#   inflating: body/training/Shoulder/69aa6a62-6df5-4a6b-9f3f-ca647541f8d9.png
#   inflating: body/training/Shoulder/69aed076-5aea-4553-ad7d-6d290dae663d.png
#   inflating: body/training/Shoulder/69b49d53-8060-4fc0-ab02-d3e148d07493.png
#   inflating: body/training/Shoulder/69bd8a11-ec43-4216-982d-6141d89c2346.png
#   inflating: body/training/Shoulder/69c03084-c514-4346-922a-17b5b0b13bab.png
#   inflating: body/training/Shoulder/69c220ec-3aa2-4593-b19e-9ad1ac403ef7.png
#   inflating: body/training/Shoulder/69c5cbbf-67d8-497b-9e2c-734dc815c4d8.png
#   inflating: body/training/Shoulder/69ca6b07-bdcb-43c1-8269-617eab93d136.png
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8x-cls.pt')

# %%
results = model.train(data='/content/body', epochs=2, imgsz=640,batch=16)
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.31 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8x-cls summary (fused): 133 layers, 56128324 parameters, 0 gradients, 153.8 GFLOPs
#
# PyTorch: starting from 'runs/classify/train4/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 4) (107.3 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 223.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 10.2s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 15.6s, saved as 'runs/classify/train4/weights/best.onnx' (214.1 MB)
#
# Export complete (24.5s)
# Results saved to /content/runs/classify/train4/weights
# Predict:         yolo predict task=classify model=runs/classify/train4/weights/best.onnx imgsz=640
# ...

# %%
# %cd /content/runs/classify/train4
# Out:
# /content/runs/classify/train4

# %%
# !zip -r parts.zip /content/runs/classify/train4
# Out:
#   adding: content/runs/classify/train4/ (stored 0%)
#   adding: content/runs/classify/train4/confusion_matrix.png (deflated 33%)
#   adding: content/runs/classify/train4/val_batch1_labels.jpg (deflated 14%)
#   adding: content/runs/classify/train4/train_batch1.jpg (deflated 14%)
#   adding: content/runs/classify/train4/train_batch2.jpg (deflated 14%)
#   adding: content/runs/classify/train4/weights/ (stored 0%)
#   adding: content/runs/classify/train4/weights/best.pt (deflated 8%)
#   adding: content/runs/classify/train4/weights/last.pt (deflated 8%)
#   adding: content/runs/classify/train4/weights/best.onnx (deflated 20%)
#   adding: content/runs/classify/train4/confusion_matrix_normalized.png (deflated 31%)
#   adding: content/runs/classify/train4/train_batch0.jpg (deflated 13%)
#   adding: content/runs/classify/train4/results.png (deflated 13%)
#   adding: content/runs/classify/train4/val_batch1_pred.jpg (deflated 14%)
# ...

# %%
from google.colab import files
files.download('parts.zip')

# %%
import shutil
shutil.copy("/content/runs/classify/train4/parts.zip","/content/drive/MyDrive/parts.zip")
# Out:
# '/content/drive/MyDrive/parts.zip'
